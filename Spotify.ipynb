# %%
#import des fonctions et des modules de notre projet
import pandas as pd
import os
import fonctions as f
import load_data as l
import part1 as p1
import cleaning as cl
import part2 as p2

# %%
#s'assurer qu'on a la bonne version de pandas 
#!pip install -q pandas==1.5.3

# %%
#télecharger les fichier dans le dict
my_tables=l.load_tables(["artists","spotify_top200_global","tracks"])

# %%
#stocker  les tables 
artists=my_tables["artists"]
top=my_tables["spotify_top200_global"]
tracks=my_tables["tracks"]

# %%
p1.top_artists(artists)

# %%
#clean la table
adj_tracks=cl.clean_tracks(tracks)

# %%
p1.chansons_par_annee(adj_tracks)

# %%
p1.artistes_top_200(top)

# %%
p1.correlation_popularite(adj_tracks)
